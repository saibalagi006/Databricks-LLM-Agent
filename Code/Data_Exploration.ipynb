# %%
# %sql

select * from llmagent.dev.product_details
limit 10

# %%
# %sql

select * from llmagent.dev.products
limit 10

# %%
# %sql

select * from llmagent.dev.product_details pd
join llmagent.dev.products p on pd.product_name = p.product_name
limit 10
